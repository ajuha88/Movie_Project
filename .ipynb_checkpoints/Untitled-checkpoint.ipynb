# %%
# import necessary libraries
import pandas as pd
from sqlalchemy import func, create_engine
from sqlalchemy import Column,Integer,String,Float
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import declarative_base

Base=declarative_base()

# %%
engine = create_engine("sqlite:///movies_db.sqlite")
Base.metadata.create_all(engine)
result = engine.execute("SELECT * FROM movie_info LIMIT 5;")

session = Session(bind=engine)

for row in result:
    print(row)
# Out:
# (0, 'The Shawshank Redemption', '14 Oct 1994', 'R', 'Drama', '9.3/10', '80', 'USA', 'Tim Robbins, Morgan Freeman, Bob Gunton, William Sadler')
# (1, 'The Godfather', '24 Mar 1972', 'R', 'Crime, Drama', '9.2/10', '100', 'USA', 'Marlon Brando, Al Pacino, James Caan, Richard S. Castellano')
# (2, 'The Godfather: Part II', '20 Dec 1974', 'R', 'Crime, Drama', '9.0/10', '90', 'USA', 'Al Pacino, Robert Duvall, Diane Keaton, Robert De Niro')
# (3, 'The Dark Knight', '18 Jul 2008', 'PG-13', 'Action, Crime, Drama, Thriller', '9.0/10', '84', 'USA, UK', 'Christian Bale, Heath Ledger, Aaron Eckhart, Michael Caine')
# (4, '12 Angry Men', '10 Apr 1957', 'Not Rated', 'Crime, Drama', '8.9/10', '96', 'USA', 'Martin Balsam, John Fiedler, Lee J. Cobb, E.G. Marshall')

# %%
class movies(Base):
    __tablename__ = 'movie_info'

    index = Column(Integer, primary_key=True)
    Title = Column(String(64))
    Date = Column(String)
    Rated = Column(String)
    Genre = Column(String)
    Ratings = Column(String)
    Imdb = Column(String)
    Country = Column(String)
    Actors = Column(String)

# %%
results = session.query(movies.Title,movies.Rated,movies.Imdb,movies.Genre,movies.Country).all()

# %%
Title = [result[0] for result in results]
Rated = [result[1] for result in results]
Ratingimdb = [result[2] for result in results]
Genre = [result[3] for result in results]
Country = [result[4] for result in results]

Ratingimdb

Ratingsimdb = []

for x in Ratingimdb:
    if x =='N/A':
        pass
    else:
        Ratingsimdb.append(int(x))

Ratingsimdb
# Out:
# [80,
#  100,
#  90,
#  84,
#  96,
#  93,
#  94,
#  94,
#  90,
#  66,
#  92,
#  82,
#  82,
#  74,
#  87,
#  80,
#  89,
#  73,
#  98,
#  65,
#  79,
#  90,
#  85,
#  89,
#  59,
#  96,
#  91,
#  77,
#  64,
#  61,
#  74,
#  97,
#  62,
#  100,
#  80,
#  85,
#  96,
#  57,
#  85,
#  87,
#  75,
#  88,
#  100,
#  83,
#  85,
#  67,
#  87,
#  66,
#  94,
#  80,
#  89,
#  80,
#  89,
#  96,
#  68,
#  63,
#  81,
#  95,
#  76,
#  78,
#  84,
#  86,
#  81,
#  86,
#  100,
#  68,
#  100,
#  98,
#  79,
#  79,
#  58,
#  93,
#  68,
#  67,
#  82,
#  89,
#  95,
#  100,
#  80,
#  69,
#  99,
#  95,
#  94,
#  69,
#  76,
#  87,
#  70,
#  80,
#  92,
#  77,
#  55,
#  65,
#  74,
#  93,
#  98,
#  90,
#  95,
#  65,
#  88,
#  98,
#  70,
#  97,
#  82,
#  85,
#  72,
#  99,
#  76,
#  80,
#  69,
#  89,
#  87,
#  98,
#  92,
#  86,
#  97,
#  80,
#  96,
#  60,
#  80,
#  87,
#  72,
#  66,
#  73,
#  91,
#  88,
#  77,
#  75,
#  94,
#  62,
#  73,
#  86,
#  71,
#  89,
#  75,
#  91,
#  93,
#  83,
#  64,
#  97,
#  57,
#  85,
#  72,
# ...

# %%
Rating

Rating = [y for x in Rating for y in x.split('/')]


Rating

Ratings = [];

for x in Rating:
    if x == '10':
        pass
    else: 
        Ratings.append(x)
        
Ratings
# Out:
# ['9.3',
#  '9.2',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '5.2',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.5',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.3',
#  '8.4',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.4',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.5',
#  '8.4',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
# ...

# %%
results = session.query(movies.Genre).all()
lists = []
for result in results:
    lists.append(result[0])

newlist_genre = [y for x in lists for y in x.split(', ')]

newlist_genre
# Out:
# ['Drama',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Drama',
#  'History',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Crime',
#  'Drama',
#  'Western',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Drama',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Thriller',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Drama',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Action',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'War',
#  'Animation',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Mystery',
#  'Drama',
#  'War',
#  'Crime',
#  'Mystery',
#  'Thriller',
# ...
